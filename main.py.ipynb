# %%
from ViT import TransformerModel

t = TransformerModel(batch_size=64)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([4]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([4, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
t.train()
# Out:
# Epoch 1/10
# Train Loss: 0.3897, Train Accuracy: 0.8600
# Val Loss: 0.1116, Val Accuracy: 0.9744
# Epoch 2/10
# Train Loss: 0.0923, Train Accuracy: 0.9697
# Val Loss: 0.0512, Val Accuracy: 0.9829
# Epoch 3/10
# Train Loss: 0.0413, Train Accuracy: 0.9866
# Val Loss: 0.0343, Val Accuracy: 0.9915
# Epoch 4/10
# Train Loss: 0.0260, Train Accuracy: 0.9935
# Val Loss: 0.0652, Val Accuracy: 0.9744
# Epoch 5/10
# Train Loss: 0.0160, Train Accuracy: 0.9949
# Val Loss: 0.0133, Val Accuracy: 0.9986
# Epoch 6/10
# Train Loss: 0.0049, Train Accuracy: 0.9990
# Val Loss: 0.0102, Val Accuracy: 0.9986
# Epoch 7/10
# Train Loss: 0.0066, Train Accuracy: 0.9986
# Val Loss: 0.0133, Val Accuracy: 0.9957
# Epoch 8/10
# Train Loss: 0.0089, Train Accuracy: 0.9978
# Val Loss: 0.0113, Val Accuracy: 0.9986
# Epoch 9/10
# Train Loss: 0.0100, Train Accuracy: 0.9972
# Val Loss: 0.0175, Val Accuracy: 0.9929
# Epoch 10/10
# Train Loss: 0.0060, Train Accuracy: 0.9990
# Val Loss: 0.0121, Val Accuracy: 0.9957

# %%
t.plot_accuracy()
t.plot_loss()

# %%
t.save('test_model')

# %%
t.plot_confusion_matrix()

# %%
import cv2
import matplotlib.pyplot as plt

def plot_image(image_path):
    image = cv2.imread(image_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()


healthy_path = './test_images/healthy.jpeg'
pitu_path = './test_images/pitu.jpg'
rotated_healthy = './test_images/contrast_rotated.jpg'

plot_image(healthy_path)
t.predict(healthy_path)

plot_image(pitu_path)
t.predict(pitu_path)

plot_image(rotated_healthy)
t.predict(rotated_healthy)
# Out:
# glioma: 0.01%
# healthy: 99.98%
# meningioma: 0.00%
# pituitary: 0.00%
# glioma: 0.27%
# healthy: 45.60%
# meningioma: 1.59%
# pituitary: 52.55%
# glioma: 0.01%
# healthy: 99.98%
# meningioma: 0.00%
# pituitary: 0.01%
