# %%
import torch
import random
import numpy as np

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
from ViT import TransformerModel

t = TransformerModel(batch_size=64)
# Out:
# ...
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([4]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([4, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
t.train()
# Out:
# Epoch 1/10
# Train Loss: 0.4190, Train Accuracy: 0.8507
# Val Loss: 0.1300, Val Accuracy: 0.9601
# Epoch 2/10
# Train Loss: 0.1012, Train Accuracy: 0.9652
# Val Loss: 0.0736, Val Accuracy: 0.9758
# Epoch 3/10
# Train Loss: 0.0396, Train Accuracy: 0.9882
# Val Loss: 0.0549, Val Accuracy: 0.9815
# Epoch 4/10
# Train Loss: 0.0206, Train Accuracy: 0.9935
# Val Loss: 0.0507, Val Accuracy: 0.9858
# Epoch 5/10
# Train Loss: 0.0227, Train Accuracy: 0.9933
# Val Loss: 0.0501, Val Accuracy: 0.9886
# Epoch 6/10
# Train Loss: 0.0098, Train Accuracy: 0.9978
# Val Loss: 0.0480, Val Accuracy: 0.9858
# Epoch 7/10
# Train Loss: 0.0048, Train Accuracy: 0.9992
# Val Loss: 0.0340, Val Accuracy: 0.9900
# Epoch 8/10
# Train Loss: 0.0050, Train Accuracy: 0.9990
# Val Loss: 0.0366, Val Accuracy: 0.9886
# Epoch 9/10
# Train Loss: 0.0205, Train Accuracy: 0.9921
# Val Loss: 0.0473, Val Accuracy: 0.9872
# Epoch 10/10
# Train Loss: 0.0137, Train Accuracy: 0.9955
# Val Loss: 0.0429, Val Accuracy: 0.9872

# %%
t.plot_accuracy()
t.plot_loss()

# %%
t.save('test_model')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t.save('test_model')
#
# File S:\JavaClass\Python\AIProject\ViT.py:175, in TransformerModel.save(self, model_name)
#     173 if not os.path.exists(path):
#     174     os.mkdir(path)
# --> 175 torch.save(self.model.state_dict, path)
#
# File S:\Users\salim\AppData\Local\Programs\Python\AIProject\lib\site-packages\torch\serialization.py:849, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     846 _check_save_filelike(f)
#     848 if _use_new_zipfile_serialization:
# --> 849     with _open_zipfile_writer(f) as opened_zipfile:
#     850         _save(
#     851             obj,
#     852             opened_zipfile,
#    (...)
#     855             _disable_byteorder_record,
#     856         )
#     857         return
#
# ...

# %%
t.plot_confusion_matrix()

# %%
import cv2
import matplotlib.pyplot as plt

def plot_image(image_path):
    image = cv2.imread(image_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()


healthy_path = './test_images/healthy.jpeg'
pitu_path = './test_images/pitu.jpg'
rotated_healthy = './test_images/contrast_rotated.jpg'

plot_image(healthy_path)
t.predict(healthy_path)

plot_image(pitu_path)
t.predict(pitu_path)

plot_image(rotated_healthy)
t.predict(rotated_healthy)
# Out:
# glioma: 0.01%
# healthy: 99.97%
# meningioma: 0.00%
# pituitary: 0.01%
# glioma: 0.09%
# healthy: 43.66%
# meningioma: 2.26%
# pituitary: 53.99%
# glioma: 0.01%
# healthy: 99.97%
# meningioma: 0.01%
# pituitary: 0.01%

# %%
from BrainTumorCNN import BrainTumorCNN
from CNNTrainer import Trainer

model = BrainTumorCNN()
trainer = Trainer(model)

trainer.train(num_epochs=20)
# Out:
# ...
# Epoch 1/20, Train Loss: 489.7738, Train Accuracy: 0.6751
# Validation Loss: 14.6547, Validation Accuracy: 0.7892
# Epoch 2/20, Train Loss: 89.0532, Train Accuracy: 0.8013
# Validation Loss: 11.0011, Validation Accuracy: 0.8177
# Epoch 3/20, Train Loss: 65.0510, Train Accuracy: 0.8411
# Validation Loss: 8.0324, Validation Accuracy: 0.8604
# Epoch 4/20, Train Loss: 53.9404, Train Accuracy: 0.8676
# Validation Loss: 7.4334, Validation Accuracy: 0.8647
# Epoch 5/20, Train Loss: 50.9201, Train Accuracy: 0.8712
# Validation Loss: 8.4381, Validation Accuracy: 0.8675
# Epoch 6/20, Train Loss: 44.8221, Train Accuracy: 0.8910
# Validation Loss: 6.1456, Validation Accuracy: 0.8932
# Epoch 7/20, Train Loss: 33.2468, Train Accuracy: 0.9190
# Validation Loss: 9.6384, Validation Accuracy: 0.8262
# Epoch 8/20, Train Loss: 34.7845, Train Accuracy: 0.9113
# Validation Loss: 6.7375, Validation Accuracy: 0.8789
# Epoch 9/20, Train Loss: 34.6449, Train Accuracy: 0.9184
# ...

# %%
import cv2
import matplotlib.pyplot as plt

trainer.test()

def plot_image(image_path):
    image = cv2.imread(image_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()


healthy_path = './test_images/healthy.jpeg'
pitu_path = './test_images/pitu.jpg'
rotated_healthy = './test_images/rotated.jpg'

plot_image(healthy_path)
trainer.predict(healthy_path)

plot_image(pitu_path)
trainer.predict(pitu_path)

plot_image(rotated_healthy)
trainer.predict(rotated_healthy)
# Out:
# Test Loss: 5.8569, Test Accuracy: 0.9630
# glioma: 0.01%
# healthy: 99.99%
# meningioma: 0.00%
# pituitary: 0.00%
# glioma: 0.00%
# healthy: 0.04%
# meningioma: 0.00%
# pituitary: 99.96%
# glioma: 99.92%
# healthy: 0.00%
# meningioma: 0.08%
# pituitary: 0.00%

# %%
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt
from torchvision import transforms
from PIL import Image
from gradcam import GradCAM

def plot_grad_cam(image_path, model, target_layer, target_class, device):
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.5] * 3, [0.5] * 3)
    ])
    image = Image.open(image_path).convert("RGB")
    input_tensor = transform(image).unsqueeze(0).to(device)

    grad_cam = GradCAM(model, target_layer)

    # Compute heatmap
    heatmap = grad_cam.compute_heatmap(input_tensor, target_class)
    heatmap = cv2.applyColorMap(np.uint8(255 * heatmap), cv2.COLORMAP_JET)
    heatmap = np.float32(heatmap) / 255

    image_resized = np.array(image.resize((224, 224))) / 255.0

    overlay = 0.5 * heatmap + 0.5 * image_resized
    overlay = overlay / np.max(overlay)

    # Plot the image with the heatmap
    plt.imshow(overlay)
    plt.axis('off')
    plt.show()


target_layer = trainer.model.conv3
image_path = "./test_images/rotated.jpg"

plot_grad_cam(healthy_path, trainer.model, target_layer, 1, 'cuda')
plot_grad_cam(pitu_path, trainer.model, target_layer, 3, 'cuda')
plot_grad_cam(rotated_healthy, trainer.model, target_layer, 1, 'cuda')
# Out:
# S:\Users\salim\AppData\Local\Programs\Python\AIProject\lib\site-packages\torch\nn\modules\module.py:1827: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)

# %%
trainer.plot_confusion_matrix()
trainer.plot_loss()
trainer.plot_accuracy()
